# %%
# 常规步骤，导入一些包
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Make the graphs a bit prettier, and bigger
plt.style.use('default')

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

plt.rcParams['figure.figsize'] = (15, 5)

complaints = pd.read_csv('data/311-service-requests.csv')
# Out:
# D:\MachineLearning\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # 3.1 只选择噪音投诉看看

# %% [markdown]
# ## 我想知道哪个镇有最多的噪音投诉。首先，我们看看数据是什么样子

# %%
complaints.head(5)
# 输入com后点击Tab会弹出智能选择，节约时间
# Out:
#    Unique Key            Created Date             Closed Date Agency                              Agency Name           Complaint Type                    Descriptor        Location Type Incident Zip  Incident Address      Street Name   Cross Street 1                    Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type      City Landmark Facility Type    Status                Due Date Resolution Action Updated Date Community Board    Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %% [markdown]
# ## 为了获得噪音投诉的数据，我们要看行标是‘Noise - Street/Sidewalk’的数据。

# %%
noise_complaints = complaints[complaints['Complaint Type'] == 'Noise - Street/Sidewalk']
noise_complaints.head(5)
# Out:
#     Unique Key            Created Date             Closed Date Agency                      Agency Name           Complaint Type        Descriptor    Location Type Incident Zip     Incident Address      Street Name    Cross Street 1  Cross Street 2 Intersection Street 1 Intersection Street 2 Address Type           City Landmark Facility Type    Status                Due Date Resolution Action Updated Date   Community Board        Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name   Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %% [markdown]
# ## 我们现在看看上面是怎么工作的， 分成两部分：

# %%
complaints['Complaint Type'] == 'Noise - Street/Sidewalk'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16         True
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25         True
# 26        False
# 27        False
# 28         True
# 29        False
#           ...
# 111039    False
# 111040    False
# 111041    False
# 111042     True
# 111043    False
# 111044     True
# 111045    False
# 111046    False
# 111047    False
# 111048     True
# 111049    False
# 111050    False
# 111051    False
# 111052    False
# 111053    False
# 111054     True
# 111055    False
# 111056    False
# 111057    False
# 111058    False
# 111059     True
# 111060    False
# 111061    False
# 111062    False
# ...

# %% [markdown]
# ## 上面是个包含了很多的True 和False的数列。 我们如果用这个数列做DataFrame的下标，我们会获得那些布尔值为True的行。 我们获得的新的DataFrame的行数一定等于该数列中True的个数。我们也可以用多个判断条件去选择。比如：

# %%
is_noise = complaints['Complaint Type'] == "Noise - Street/Sidewalk"
in_brooklyn = complaints['Borough'] == "BROOKLYN"
complaints[is_noise & in_brooklyn].head(5)
# Out:
#      Unique Key            Created Date             Closed Date Agency                      Agency Name           Complaint Type        Descriptor    Location Type Incident Zip    Incident Address      Street Name     Cross Street 1  Cross Street 2 Intersection Street 1 Intersection Street 2  Address Type      City Landmark Facility Type  Status                Due Date Resolution Action Updated Date Community Board   Borough  X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name Park Borough  School Name School Number School Region  School Code School Phone Number School Address  School City School State   School Zip School Not Found  School or Citywide Complaint Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude                                  Location
# ...

# %% [markdown]
# # 3.2 Numpy数组介绍（偏题）
# ## 里面一个列的类型是pd.Series

# %%
pd.Series([1, 2, 3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# ## pandas Series是一个内置的numpy数列，如果你给最后加上.values, 就可以得到内部的numpy数列。

# %%
np.array([1, 2,3])
# Out:
# array([1, 2, 3])

# %%
pd.Series([1,2,3]).values
# Out:
# array([1, 2, 3], dtype=int64)

# %% [markdown]
# ## 所以，实际上上面的选择行是因为numpy数组就是这样工作的

# %%
arr = np.array([1, 2, 3])
arr != 2
# Out:
# array([ True, False,  True], dtype=bool)

# %%
arr[arr != 2]
# Out:
# array([1, 3])

# %% [markdown]
# # 3.3 最后，那个镇的噪音投诉最多？

# %%
is_noise = complaints['Complaint Type'] == "Noise - Street/Sidewalk"
noise_complaints = complaints[is_noise]
noise_complaints['Borough'].value_counts()
# Out:
# MANHATTAN        917
# BROOKLYN         456
# BRONX            292
# QUEENS           226
# STATEN ISLAND     36
# Unspecified        1
# Name: Borough, dtype: int64

# %% [markdown]
# ## 可以看出MANHATTAN的投诉案例最多。但是，如果我们如果想用投诉的总数去除它，让它变得更有意义呢？

# %%
noise_complaint_counts = noise_complaints['Borough'].value_counts()
complaint_counts = complaints['Borough'].value_counts()

# %%
noise_complaint_counts / complaint_counts
# Out:
# BRONX            0.014833
# BROOKLYN         0.013864
# MANHATTAN        0.037755
# QUEENS           0.010143
# STATEN ISLAND    0.007474
# Unspecified      0.000141
# Name: Borough, dtype: float64

# %%
(noise_complaint_counts / complaint_counts.astype(float)).plot(kind='bar')
